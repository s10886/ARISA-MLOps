# %% [markdown]
# ## Version 2 - Boss/client feedback
# Oh no, the client has taken a look at our work and they are not happy.
# They spend a lot of money on that data and we have thrown away two whole columns without good reason.
# We need to update our feature engineering to include features based on the cabin and name columns,
# which should also hopefully improve the performance since they feel 74% is a little too low to put into production.
# Also the client doesn't know what to do with a .cbm file, they just want to be able to get new predictions whenever they get new data coming in.
# Let's first implement the new features so that we use the dropped columns and then we can think about getting the predictions to the client somehow.

# %%
# !pip install catboost matplotlib pandas scikit-learn kaggle optuna ipywidgets kaleido shap
# Out:
# Requirement already satisfied: catboost in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (1.2.7)
# Requirement already satisfied: matplotlib in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (3.10.1)
# Requirement already satisfied: pandas in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (2.2.3)
# Requirement already satisfied: scikit-learn in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (1.6.1)
# Requirement already satisfied: kaggle in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (1.6.17)
# Requirement already satisfied: optuna in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (4.2.1)
# Requirement already satisfied: ipywidgets in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (8.1.5)
# Requirement already satisfied: kaleido in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (0.2.1)
# Requirement already satisfied: shap in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (0.47.0)
# Requirement already satisfied: graphviz in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from catboost) (0.20.3)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from catboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from catboost) (1.15.2)
# Requirement already satisfied: plotly in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from catboost) (6.0.0)
# Requirement already satisfied: six in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from catboost) (1.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: certifi>=2023.7.22 in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from kaggle) (2025.1.31)
# Requirement already satisfied: requests in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from kaggle) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from kaggle) (4.67.1)
# Requirement already satisfied: python-slugify in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from kaggle) (2.3.0)
# Requirement already satisfied: bleach in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from kaggle) (6.2.0)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from optuna) (1.15.1)
# Requirement already satisfied: colorlog in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from optuna) (6.9.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from optuna) (2.0.38)
# Requirement already satisfied: PyYAML in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from optuna) (6.0.2)
# Requirement already satisfied: comm>=0.1.3 in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from ipywidgets) (9.0.1)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: slicer==0.0.8 in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from shap) (0.0.8)
# Requirement already satisfied: numba>=0.54 in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from shap) (0.61.0)
# Requirement already satisfied: cloudpickle in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from shap) (3.1.1)
# Requirement already satisfied: typing-extensions in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from shap) (4.12.2)
# Requirement already satisfied: Mako in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from alembic>=1.5.0->optuna) (1.3.9)
# Requirement already satisfied: colorama in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from numba>=0.54->shap) (0.44.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: webencodings in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from plotly->catboost) (1.29.1)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from requests->kaggle) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from requests->kaggle) (3.10)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Requirement already satisfied: executing>=1.2.0 in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\karolina\desktop\studia mgr\podyplomówka\mlops\labs\.venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)

# %% [markdown]
# Getting the data again.

# %%
import os
import zipfile
from pathlib import Path
from kaggle.api.kaggle_api_extended import KaggleApi

api = KaggleApi()
api.authenticate()

dataset = "titanic"  # original competition dataset
dataset_test = "wesleyhowe/titanic-labelled-test-set"  # test set augmented with target labels
download_folder = Path("data/titanic")
zip_path = download_folder / "titanic.zip"
download_folder.mkdir(parents=True, exist_ok=True)

api.competition_download_files(dataset, path=str(download_folder))
api.dataset_download_files(dataset_test, path=str(download_folder), unzip=True)

with zipfile.ZipFile(zip_path, "r") as zip_ref:
    zip_ref.extractall(str(download_folder))

os.remove(zip_path)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/wesleyhowe/titanic-labelled-test-set

# %%
# !dir "./data/titanic"
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is C455-2446
#
#  Directory of c:\Users\Karolina\Desktop\Studia mgr\Podyplom�wka\MLOps\Labs\ARISA-MLOps\data\titanic
#
# 07.03.2025  19:28    <DIR>          .
# 07.03.2025  19:28    <DIR>          ..
# 07.03.2025  19:28             3�258 gender_submission.csv
# 07.03.2025  19:28            28�629 test.csv
# 07.03.2025  19:28            30�234 test_augmented.csv
# 07.03.2025  19:28            61�194 train.csv
#                4 File(s)        123�315 bytes
#                2 Dir(s)  706�756�501�504 bytes free

# %% [markdown]
# Read in the data again and dropping passengerId, and now only ticket, since we will be using Name and Cabin.

# %%
import pandas as pd

df_train = pd.read_csv(download_folder / "train.csv")
df_ids = df_train.pop("PassengerId")  # set aside PassengerId

df_train.sample(10)

df_train = df_train.drop(columns=["Ticket"])
df_train.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0    male  22.0      1      0   7.2500   NaN        S
# 1  female  38.0      1      0  71.2833   C85        C
# 2  female  26.0      0      0   7.9250   NaN        S
# 3  female  35.0      1      0  53.1000  C123        S
# 4    male  35.0      0      0   8.0500   NaN        S

# %% [markdown]
# Quick regex match on the titles

# %%
import re
def extract_title(name):
    match = re.search(r',\s*([\w\s]+)\.', name)
    return match.group(1) if match else None
df_train["Title"] = df_train["Name"].apply(extract_title)
df_train.sample(5)
# Out:
#      Survived  Pclass                                  Name     Sex   Age  \
# 429         1       3    Pickard, Mr. Berk (Berk Trembisky)    male  32.0
# 885         0       3  Rice, Mrs. William (Margaret Norton)  female  39.0
# 316         1       2   Kantor, Mrs. Sinai (Miriam Sternin)  female  24.0
# 522         0       3                    Lahoud, Mr. Sarkis    male   NaN
# 77          0       3              Moutal, Mr. Rahamin Haim    male   NaN
#
#      SibSp  Parch    Fare Cabin Embarked Title
# 429      0      0   8.050   E10        S    Mr
# 885      0      5  29.125   NaN        Q   Mrs
# 316      1      0  26.000   NaN        S   Mrs
# 522      0      0   7.225   NaN        C    Mr
# 77       0      0   8.050   NaN        S    Mr

# %% [markdown]
# Looks about right:

# %%
df_train["Title"].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Don', 'Rev', 'Dr', 'Mme', 'Ms',
#        'Major', 'Lady', 'Sir', 'Mlle', 'Col', 'Capt', 'the Countess',
#        'Jonkheer'], dtype=object)

# %% [markdown]
# And for the Cabin we split into deck and cabin number:

# %%
# pattern to match a letter followed by a number
pattern = r'([A-Za-z]+)(\d+)'

# run pattern on Cabin to extract all matches
matches = df_train['Cabin'].str.extractall(pattern)
matches.reset_index(inplace=True)

# create a new column for each letter and number matched
result = matches.pivot(index='level_0', columns='match', values=[0, 1])
result.columns = [f"{col[0]}_{col[1]}" for col in result.columns]

# join to original train dataframe
df_train = df_train.join(result[["0_0", "1_0"]])

# fill nans
df_train["1_0"] = df_train["1_0"].astype(float)
df_train = df_train.fillna({"0_0": "N", "1_0": df_train["1_0"].mean()})
df_train["1_0"] = df_train["1_0"].astype(int)

# rename new columns and drop old ones
df_train = df_train.rename(columns={"0_0": "Deck", "1_0": "CabinNumber"})
df_train.drop(columns=["Cabin", "Name"], axis=1, inplace=True)

# %% [markdown]
# Fill remaining nans:

# %%
df_train = df_train.fillna({"Embarked": "N", "Age": df_train["Age"].mean()})
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Survived     891 non-null    int64
#  1   Pclass       891 non-null    int64
#  2   Sex          891 non-null    object
#  3   Age          891 non-null    float64
#  4   SibSp        891 non-null    int64
#  5   Parch        891 non-null    int64
#  6   Fare         891 non-null    float64
#  7   Embarked     891 non-null    object
#  8   Title        891 non-null    object
#  9   Deck         891 non-null    object
#  10  CabinNumber  891 non-null    int32
# dtypes: float64(2), int32(1), int64(4), object(4)
# memory usage: 73.2+ KB

# %% [markdown]
# Get indices for categorical columns now including Title and Deck (CabinNumber is numerical):

# %%
categorical = [
    "Pclass", 
    "Sex", 
    "Embarked",
    "Deck",
    "Title"
]

y_train = df_train.pop("Survived")
X_train = df_train

categorical_indices = [X_train.columns.get_loc(col) for col in categorical if col in X_train.columns]
categorical_indices
# Out:
# [0, 1, 6, 8, 7]

# %% [markdown]
# And run the hyperparameter optimization:

# %%
import joblib
import optuna
from sklearn.model_selection import train_test_split
from catboost import CatBoostClassifier, Pool, cv

outfolder = Path("results")
outfolder.mkdir(parents=True, exist_ok=True)

best_params_path = outfolder / "best_params_v2.pkl"

if not best_params_path.is_file():
    X_train_opt, X_val_opt, y_train_opt, y_val_opt = train_test_split(X_train, y_train, test_size=0.25, random_state=42)
    
    def objective(trial):
        params = {
            "depth": trial.suggest_int("depth", 2, 10),
            "learning_rate": trial.suggest_float("learning_rate", 1e-4, 0.3),
            "iterations": trial.suggest_int("iterations", 50, 300),
            "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1e-5, 100.0, log=True),
            "bagging_temperature": trial.suggest_float("bagging_temperature", 0.01, 1),
            "random_strength": trial.suggest_float("random_strength", 1e-5, 100.0, log=True)
        }
        model = CatBoostClassifier(**params, verbose=0)
        model.fit(X_train_opt, y_train_opt, eval_set=(X_val_opt, y_val_opt), cat_features=categorical_indices, early_stopping_rounds=50)
        return model.get_best_score()["validation"]["Logloss"]
    study = optuna.create_study(direction="minimize")
    study.optimize(objective, n_trials=50)
    
    joblib.dump(study.best_params, best_params_path)
    params = study.best_params
else:
    params = joblib.load(best_params_path)
print("Best Parameters:", params)
# Out:
# Best Parameters: {'depth': 4, 'learning_rate': 0.22006324169065175, 'iterations': 163, 'l2_leaf_reg': 0.031900004970318356, 'bagging_temperature': 0.5964381011651683, 'random_strength': 0.0013931822006011051}

# %% [markdown]
# Do cross validation again:

# %%
params["eval_metric"] = "F1"
params["loss_function"] = "Logloss"

model = CatBoostClassifier(
    **params,
    verbose=True
)

data = Pool(X_train, y_train, cat_features=categorical_indices)

cv_results = cv(
    params=params,
    pool=data,
    fold_count=5,
    partition_random_seed=42,
    shuffle=True,
)

cv_results.to_csv(outfolder / "cv_results_v2.csv", index=False)
# Out:
# Training on fold [0/5]
# 0:	learn: 0.7471264	test: 0.7692308	best: 0.7692308 (0)	total: 169ms	remaining: 27.3s
# 1:	learn: 0.7533461	test: 0.7938931	best: 0.7938931 (1)	total: 202ms	remaining: 16.3s
# 2:	learn: 0.7557252	test: 0.7938931	best: 0.7938931 (1)	total: 221ms	remaining: 11.8s
# 3:	learn: 0.7600768	test: 0.7938931	best: 0.7938931 (1)	total: 241ms	remaining: 9.58s
# 4:	learn: 0.7600768	test: 0.7938931	best: 0.7938931 (1)	total: 259ms	remaining: 8.18s
# 5:	learn: 0.7600768	test: 0.7938931	best: 0.7938931 (1)	total: 278ms	remaining: 7.27s
# 6:	learn: 0.7635659	test: 0.8000000	best: 0.8000000 (6)	total: 300ms	remaining: 6.7s
# 7:	learn: 0.7659574	test: 0.8000000	best: 0.8000000 (6)	total: 320ms	remaining: 6.21s
# 8:	learn: 0.7730769	test: 0.7938931	best: 0.8000000 (6)	total: 339ms	remaining: 5.79s
# 9:	learn: 0.7760618	test: 0.7938931	best: 0.8000000 (6)	total: 360ms	remaining: 5.51s
# 10:	learn: 0.7775629	test: 0.7938931	best: 0.8000000 (6)	total: 385ms	remaining: 5.32s
# 11:	learn: 0.7755906	test: 0.7906977	best: 0.8000000 (6)	total: 407ms	remaining: 5.12s
# 12:	learn: 0.7898833	test: 0.7906977	best: 0.8000000 (6)	total: 425ms	remaining: 4.9s
# 13:	learn: 0.7945736	test: 0.7906977	best: 0.8000000 (6)	total: 446ms	remaining: 4.74s
# 14:	learn: 0.8084291	test: 0.7906977	best: 0.8000000 (6)	total: 469ms	remaining: 4.63s
# 15:	learn: 0.8160920	test: 0.7968750	best: 0.8000000 (6)	total: 492ms	remaining: 4.52s
# 16:	learn: 0.8062622	test: 0.7840000	best: 0.8000000 (6)	total: 515ms	remaining: 4.42s
# 17:	learn: 0.8201161	test: 0.8031496	best: 0.8031496 (17)	total: 536ms	remaining: 4.32s
# 18:	learn: 0.8217054	test: 0.8031496	best: 0.8031496 (17)	total: 555ms	remaining: 4.21s
# 19:	learn: 0.8171206	test: 0.8031496	best: 0.8031496 (17)	total: 579ms	remaining: 4.14s
# 20:	learn: 0.8171206	test: 0.8031496	best: 0.8031496 (17)	total: 601ms	remaining: 4.07s
# 21:	learn: 0.8194175	test: 0.8125000	best: 0.8125000 (21)	total: 626ms	remaining: 4.01s
# 22:	learn: 0.8156863	test: 0.7840000	best: 0.8125000 (21)	total: 644ms	remaining: 3.92s
# 23:	learn: 0.8156863	test: 0.7903226	best: 0.8125000 (21)	total: 660ms	remaining: 3.82s
# 24:	learn: 0.8149606	test: 0.7840000	best: 0.8125000 (21)	total: 676ms	remaining: 3.73s
# 25:	learn: 0.8251473	test: 0.8095238	best: 0.8125000 (21)	total: 696ms	remaining: 3.67s
# 26:	learn: 0.8219178	test: 0.8095238	best: 0.8125000 (21)	total: 713ms	remaining: 3.59s
# 27:	learn: 0.8219178	test: 0.8095238	best: 0.8125000 (21)	total: 731ms	remaining: 3.52s
# 28:	learn: 0.8219178	test: 0.8095238	best: 0.8125000 (21)	total: 750ms	remaining: 3.47s
# 29:	learn: 0.8260870	test: 0.8372093	best: 0.8372093 (29)	total: 767ms	remaining: 3.4s
# 30:	learn: 0.8274510	test: 0.8372093	best: 0.8372093 (29)	total: 785ms	remaining: 3.34s
# 31:	learn: 0.8290766	test: 0.8372093	best: 0.8372093 (29)	total: 803ms	remaining: 3.29s
# 32:	learn: 0.8258317	test: 0.8281250	best: 0.8372093 (29)	total: 824ms	remaining: 3.25s
# 33:	learn: 0.8290766	test: 0.8461538	best: 0.8461538 (33)	total: 845ms	remaining: 3.21s
# 34:	learn: 0.8330059	test: 0.8461538	best: 0.8461538 (33)	total: 864ms	remaining: 3.16s
# 35:	learn: 0.8414873	test: 0.8461538	best: 0.8461538 (33)	total: 882ms	remaining: 3.11s
# 36:	learn: 0.8414873	test: 0.8461538	best: 0.8461538 (33)	total: 900ms	remaining: 3.06s
# 37:	learn: 0.8385827	test: 0.8461538	best: 0.8461538 (33)	total: 920ms	remaining: 3.02s
# 38:	learn: 0.8425197	test: 0.8396947	best: 0.8461538 (33)	total: 937ms	remaining: 2.98s
# 39:	learn: 0.8454012	test: 0.8396947	best: 0.8461538 (33)	total: 953ms	remaining: 2.93s
# 40:	learn: 0.8454012	test: 0.8307692	best: 0.8461538 (33)	total: 968ms	remaining: 2.88s
# 41:	learn: 0.8476562	test: 0.8307692	best: 0.8461538 (33)	total: 983ms	remaining: 2.83s
# 42:	learn: 0.8476562	test: 0.8372093	best: 0.8461538 (33)	total: 999ms	remaining: 2.79s
# 43:	learn: 0.8538012	test: 0.8372093	best: 0.8461538 (33)	total: 1.01s	remaining: 2.75s
# 44:	learn: 0.8593750	test: 0.8372093	best: 0.8461538 (33)	total: 1.03s	remaining: 2.71s
# 45:	learn: 0.8610568	test: 0.8372093	best: 0.8461538 (33)	total: 1.06s	remaining: 2.7s
# 46:	learn: 0.8610568	test: 0.8281250	best: 0.8461538 (33)	total: 1.08s	remaining: 2.67s
# 47:	learn: 0.8610568	test: 0.8188976	best: 0.8461538 (33)	total: 1.1s	remaining: 2.65s
# 48:	learn: 0.8582677	test: 0.8281250	best: 0.8461538 (33)	total: 1.13s	remaining: 2.62s
# 49:	learn: 0.8605108	test: 0.8000000	best: 0.8461538 (33)	total: 1.15s	remaining: 2.59s
# 50:	learn: 0.8610568	test: 0.7936508	best: 0.8461538 (33)	total: 1.17s	remaining: 2.56s
# 51:	learn: 0.8593750	test: 0.8031496	best: 0.8461538 (33)	total: 1.19s	remaining: 2.53s
# 52:	learn: 0.8632813	test: 0.8125000	best: 0.8461538 (33)	total: 1.2s	remaining: 2.5s
# 53:	learn: 0.8615984	test: 0.8125000	best: 0.8461538 (33)	total: 1.22s	remaining: 2.46s
# 54:	learn: 0.8638132	test: 0.8125000	best: 0.8461538 (33)	total: 1.24s	remaining: 2.43s
# 55:	learn: 0.8671875	test: 0.8031496	best: 0.8461538 (33)	total: 1.25s	remaining: 2.4s
# 56:	learn: 0.8715953	test: 0.8031496	best: 0.8461538 (33)	total: 1.27s	remaining: 2.37s
# 57:	learn: 0.8693957	test: 0.8031496	best: 0.8461538 (33)	total: 1.29s	remaining: 2.33s
# 58:	learn: 0.8759690	test: 0.8125000	best: 0.8461538 (33)	total: 1.3s	remaining: 2.3s
# 59:	learn: 0.8759690	test: 0.8031496	best: 0.8461538 (33)	total: 1.32s	remaining: 2.27s
# 60:	learn: 0.8759690	test: 0.7968750	best: 0.8461538 (33)	total: 1.34s	remaining: 2.24s
# 61:	learn: 0.8759690	test: 0.8031496	best: 0.8461538 (33)	total: 1.35s	remaining: 2.21s
# 62:	learn: 0.8781431	test: 0.8031496	best: 0.8461538 (33)	total: 1.37s	remaining: 2.18s
# 63:	learn: 0.8781431	test: 0.8031496	best: 0.8461538 (33)	total: 1.39s	remaining: 2.16s
# 64:	learn: 0.8798450	test: 0.8031496	best: 0.8461538 (33)	total: 1.41s	remaining: 2.13s
# 65:	learn: 0.8798450	test: 0.8031496	best: 0.8461538 (33)	total: 1.43s	remaining: 2.1s
# 66:	learn: 0.8798450	test: 0.8031496	best: 0.8461538 (33)	total: 1.44s	remaining: 2.07s
# 67:	learn: 0.8820116	test: 0.8031496	best: 0.8461538 (33)	total: 1.47s	remaining: 2.05s
# 68:	learn: 0.8820116	test: 0.8031496	best: 0.8461538 (33)	total: 1.49s	remaining: 2.02s
# 69:	learn: 0.8841699	test: 0.8031496	best: 0.8461538 (33)	total: 1.5s	remaining: 2s
# 70:	learn: 0.8837209	test: 0.8031496	best: 0.8461538 (33)	total: 1.52s	remaining: 1.97s
# 71:	learn: 0.8880309	test: 0.8031496	best: 0.8461538 (33)	total: 1.54s	remaining: 1.95s
# 72:	learn: 0.8880309	test: 0.8031496	best: 0.8461538 (33)	total: 1.56s	remaining: 1.93s
# 73:	learn: 0.8880309	test: 0.8031496	best: 0.8461538 (33)	total: 1.58s	remaining: 1.9s
# 74:	learn: 0.8932039	test: 0.8000000	best: 0.8461538 (33)	total: 1.6s	remaining: 1.88s
# 75:	learn: 0.8953488	test: 0.8031496	best: 0.8461538 (33)	total: 1.62s	remaining: 1.85s
# 76:	learn: 0.8932039	test: 0.8031496	best: 0.8461538 (33)	total: 1.64s	remaining: 1.84s
# 77:	learn: 0.8932039	test: 0.8031496	best: 0.8461538 (33)	total: 1.67s	remaining: 1.81s
# 78:	learn: 0.8953488	test: 0.8031496	best: 0.8461538 (33)	total: 1.69s	remaining: 1.8s
# 79:	learn: 0.8953488	test: 0.8031496	best: 0.8461538 (33)	total: 1.71s	remaining: 1.78s
# 80:	learn: 0.8974855	test: 0.7936508	best: 0.8461538 (33)	total: 1.73s	remaining: 1.75s
# 81:	learn: 0.8974855	test: 0.8031496	best: 0.8461538 (33)	total: 1.75s	remaining: 1.73s
# 82:	learn: 0.8932039	test: 0.8031496	best: 0.8461538 (33)	total: 1.77s	remaining: 1.7s
# 83:	learn: 0.8953488	test: 0.7936508	best: 0.8461538 (33)	total: 1.78s	remaining: 1.68s
# 84:	learn: 0.8974855	test: 0.7936508	best: 0.8461538 (33)	total: 1.8s	remaining: 1.65s
# 85:	learn: 0.8974855	test: 0.7936508	best: 0.8461538 (33)	total: 1.82s	remaining: 1.63s
# 86:	learn: 0.8974855	test: 0.7936508	best: 0.8461538 (33)	total: 1.83s	remaining: 1.6s
# 87:	learn: 0.9034749	test: 0.7874016	best: 0.8461538 (33)	total: 1.85s	remaining: 1.58s
# 88:	learn: 0.9034749	test: 0.7874016	best: 0.8461538 (33)	total: 1.87s	remaining: 1.55s
# 89:	learn: 0.9034749	test: 0.7874016	best: 0.8461538 (33)	total: 1.89s	remaining: 1.53s
# 90:	learn: 0.9076923	test: 0.7968750	best: 0.8461538 (33)	total: 1.9s	remaining: 1.5s
# 91:	learn: 0.9076923	test: 0.7968750	best: 0.8461538 (33)	total: 1.92s	remaining: 1.48s
# 92:	learn: 0.9076923	test: 0.7968750	best: 0.8461538 (33)	total: 1.94s	remaining: 1.46s
# 93:	learn: 0.9076923	test: 0.7968750	best: 0.8461538 (33)	total: 1.96s	remaining: 1.44s
# 94:	learn: 0.9076923	test: 0.7968750	best: 0.8461538 (33)	total: 1.97s	remaining: 1.41s
# 95:	learn: 0.9076923	test: 0.7906977	best: 0.8461538 (33)	total: 1.99s	remaining: 1.39s
# 96:	learn: 0.9097889	test: 0.7968750	best: 0.8461538 (33)	total: 2s	remaining: 1.36s
# 97:	learn: 0.9097889	test: 0.8062016	best: 0.8461538 (33)	total: 2.02s	remaining: 1.34s
# 98:	learn: 0.9097889	test: 0.8000000	best: 0.8461538 (33)	total: 2.04s	remaining: 1.31s
# 99:	learn: 0.9097889	test: 0.7906977	best: 0.8461538 (33)	total: 2.05s	remaining: 1.29s
# 100:	learn: 0.9118774	test: 0.7906977	best: 0.8461538 (33)	total: 2.07s	remaining: 1.27s
# 101:	learn: 0.9139579	test: 0.7906977	best: 0.8461538 (33)	total: 2.08s	remaining: 1.25s
# 102:	learn: 0.9139579	test: 0.7906977	best: 0.8461538 (33)	total: 2.1s	remaining: 1.22s
# 103:	learn: 0.9160305	test: 0.7906977	best: 0.8461538 (33)	total: 2.12s	remaining: 1.2s
# 104:	learn: 0.9198473	test: 0.7906977	best: 0.8461538 (33)	total: 2.14s	remaining: 1.18s
# 105:	learn: 0.9216061	test: 0.8000000	best: 0.8461538 (33)	total: 2.15s	remaining: 1.16s
# 106:	learn: 0.9216061	test: 0.8000000	best: 0.8461538 (33)	total: 2.17s	remaining: 1.14s
# 107:	learn: 0.9216061	test: 0.8062016	best: 0.8461538 (33)	total: 2.19s	remaining: 1.11s
# 108:	learn: 0.9216061	test: 0.8062016	best: 0.8461538 (33)	total: 2.21s	remaining: 1.09s
# 109:	learn: 0.9236641	test: 0.8062016	best: 0.8461538 (33)	total: 2.22s	remaining: 1.07s
# 110:	learn: 0.9195402	test: 0.8062016	best: 0.8461538 (33)	total: 2.24s	remaining: 1.05s
# 111:	learn: 0.9236641	test: 0.8062016	best: 0.8461538 (33)	total: 2.25s	remaining: 1.03s
# 112:	learn: 0.9236641	test: 0.8062016	best: 0.8461538 (33)	total: 2.27s	remaining: 1s
# 113:	learn: 0.9236641	test: 0.8062016	best: 0.8461538 (33)	total: 2.29s	remaining: 983ms
# 114:	learn: 0.9257143	test: 0.8062016	best: 0.8461538 (33)	total: 2.3s	remaining: 962ms
# 115:	learn: 0.9257143	test: 0.8062016	best: 0.8461538 (33)	total: 2.32s	remaining: 942ms
# 116:	learn: 0.9257143	test: 0.8062016	best: 0.8461538 (33)	total: 2.34s	remaining: 921ms
# 117:	learn: 0.9257143	test: 0.8062016	best: 0.8461538 (33)	total: 2.37s	remaining: 902ms
# 118:	learn: 0.9318182	test: 0.8062016	best: 0.8461538 (33)	total: 2.39s	remaining: 882ms
# 119:	learn: 0.9318182	test: 0.8062016	best: 0.8461538 (33)	total: 2.4s	remaining: 862ms
# 120:	learn: 0.9335863	test: 0.7968750	best: 0.8461538 (33)	total: 2.42s	remaining: 840ms
# 121:	learn: 0.9353612	test: 0.8062016	best: 0.8461538 (33)	total: 2.44s	remaining: 819ms
# 122:	learn: 0.9335863	test: 0.8062016	best: 0.8461538 (33)	total: 2.45s	remaining: 798ms
# 151:	learn: 0.9566855	test: 0.8091603	best: 0.8461538 (33)	total: 2.96s	remaining: 214ms
# 152:	learn: 0.9566855	test: 0.8091603	best: 0.8461538 (33)	total: 2.98s	remaining: 195ms
# 153:	learn: 0.9604520	test: 0.8091603	best: 0.8461538 (33)	total: 3s	remaining: 175ms
# 154:	learn: 0.9662921	test: 0.8000000	best: 0.8461538 (33)	total: 3.01s	remaining: 155ms
# 155:	learn: 0.9662921	test: 0.8091603	best: 0.8461538 (33)	total: 3.03s	remaining: 136ms
# 156:	learn: 0.9662921	test: 0.8000000	best: 0.8461538 (33)	total: 3.04s	remaining: 116ms
# 157:	learn: 0.9662921	test: 0.8091603	best: 0.8461538 (33)	total: 3.06s	remaining: 96.8ms
# 158:	learn: 0.9662921	test: 0.8091603	best: 0.8461538 (33)	total: 3.07s	remaining: 77.3ms
# 159:	learn: 0.9662921	test: 0.8091603	best: 0.8461538 (33)	total: 3.09s	remaining: 57.9ms
# 160:	learn: 0.9662921	test: 0.8091603	best: 0.8461538 (33)	total: 3.1s	remaining: 38.6ms
# 161:	learn: 0.9662921	test: 0.8091603	best: 0.8461538 (33)	total: 3.12s	remaining: 19.3ms
# 162:	learn: 0.9662921	test: 0.8091603	best: 0.8461538 (33)	total: 3.13s	remaining: 0us
#
# bestTest = 0.8461538462
# bestIteration = 33
#
# Training on fold [1/5]
# 0:	learn: 0.7653846	test: 0.7022901	best: 0.7022901 (0)	total: 19.4ms	remaining: 3.15s
# 1:	learn: 0.7868217	test: 0.6821705	best: 0.7022901 (0)	total: 41.3ms	remaining: 3.33s
# 2:	learn: 0.7929688	test: 0.6929134	best: 0.7022901 (0)	total: 57.9ms	remaining: 3.08s
# 3:	learn: 0.7969052	test: 0.6821705	best: 0.7022901 (0)	total: 73.4ms	remaining: 2.92s
# 4:	learn: 0.8167939	test: 0.6717557	best: 0.7022901 (0)	total: 88.7ms	remaining: 2.8s
# 5:	learn: 0.8190476	test: 0.6716418	best: 0.7022901 (0)	total: 104ms	remaining: 2.71s
# 6:	learn: 0.8167939	test: 0.6716418	best: 0.7022901 (0)	total: 121ms	remaining: 2.7s
# 7:	learn: 0.8129771	test: 0.6716418	best: 0.7022901 (0)	total: 137ms	remaining: 2.65s
# 8:	learn: 0.8129771	test: 0.6716418	best: 0.7022901 (0)	total: 152ms	remaining: 2.6s
# 9:	learn: 0.8122605	test: 0.6716418	best: 0.7022901 (0)	total: 167ms	remaining: 2.56s
# 10:	learn: 0.8174905	test: 0.6716418	best: 0.7022901 (0)	total: 184ms	remaining: 2.55s
# 11:	learn: 0.8212928	test: 0.7014925	best: 0.7022901 (0)	total: 201ms	remaining: 2.53s
# 12:	learn: 0.8250951	test: 0.7014925	best: 0.7022901 (0)	total: 218ms	remaining: 2.51s
# 13:	learn: 0.8320611	test: 0.6917293	best: 0.7022901 (0)	total: 241ms	remaining: 2.56s
# 14:	learn: 0.8352490	test: 0.6969697	best: 0.7022901 (0)	total: 263ms	remaining: 2.59s
# 15:	learn: 0.8421053	test: 0.6923077	best: 0.7022901 (0)	total: 278ms	remaining: 2.55s
# 16:	learn: 0.8476562	test: 0.6771654	best: 0.7022901 (0)	total: 295ms	remaining: 2.53s
# 17:	learn: 0.8437500	test: 0.6720000	best: 0.7022901 (0)	total: 311ms	remaining: 2.51s
# 18:	learn: 0.8515625	test: 0.6720000	best: 0.7022901 (0)	total: 327ms	remaining: 2.48s
# 19:	learn: 0.8521401	test: 0.6771654	best: 0.7022901 (0)	total: 344ms	remaining: 2.46s
# 20:	learn: 0.8532290	test: 0.6875000	best: 0.7022901 (0)	total: 361ms	remaining: 2.44s
# 21:	learn: 0.8554688	test: 0.6875000	best: 0.7022901 (0)	total: 378ms	remaining: 2.42s
# 22:	learn: 0.8554688	test: 0.6875000	best: 0.7022901 (0)	total: 394ms	remaining: 2.4s
# 23:	learn: 0.8554688	test: 0.6875000	best: 0.7022901 (0)	total: 410ms	remaining: 2.37s
# 24:	learn: 0.8554688	test: 0.6875000	best: 0.7022901 (0)	total: 426ms	remaining: 2.35s
# 25:	learn: 0.8554688	test: 0.6875000	best: 0.7022901 (0)	total: 442ms	remaining: 2.33s
# 26:	learn: 0.8554688	test: 0.6875000	best: 0.7022901 (0)	total: 460ms	remaining: 2.32s
# 27:	learn: 0.8554688	test: 0.6875000	best: 0.7022901 (0)	total: 480ms	remaining: 2.31s
# 28:	learn: 0.8682171	test: 0.6821705	best: 0.7022901 (0)	total: 498ms	remaining: 2.3s
# 29:	learn: 0.8682171	test: 0.6821705	best: 0.7022901 (0)	total: 513ms	remaining: 2.27s
# 30:	learn: 0.8682171	test: 0.6821705	best: 0.7022901 (0)	total: 528ms	remaining: 2.25s
# 31:	learn: 0.8682171	test: 0.6875000	best: 0.7022901 (0)	total: 544ms	remaining: 2.23s
# 32:	learn: 0.8682171	test: 0.6821705	best: 0.7022901 (0)	total: 560ms	remaining: 2.21s
# 33:	learn: 0.8704062	test: 0.6875000	best: 0.7022901 (0)	total: 576ms	remaining: 2.19s
# 34:	learn: 0.8742747	test: 0.6771654	best: 0.7022901 (0)	total: 594ms	remaining: 2.17s
# 35:	learn: 0.8742747	test: 0.6771654	best: 0.7022901 (0)	total: 609ms	remaining: 2.15s
# 36:	learn: 0.8742747	test: 0.6771654	best: 0.7022901 (0)	total: 625ms	remaining: 2.13s
# 37:	learn: 0.8786127	test: 0.6771654	best: 0.7022901 (0)	total: 642ms	remaining: 2.11s
# 38:	learn: 0.8769231	test: 0.6825397	best: 0.7022901 (0)	total: 658ms	remaining: 2.09s
# 39:	learn: 0.8769231	test: 0.6825397	best: 0.7022901 (0)	total: 676ms	remaining: 2.08s
# 40:	learn: 0.8790787	test: 0.6825397	best: 0.7022901 (0)	total: 699ms	remaining: 2.08s
# 41:	learn: 0.8769231	test: 0.6825397	best: 0.7022901 (0)	total: 716ms	remaining: 2.06s
# 42:	learn: 0.8884615	test: 0.6720000	best: 0.7022901 (0)	total: 732ms	remaining: 2.04s
# 43:	learn: 0.8923077	test: 0.6771654	best: 0.7022901 (0)	total: 749ms	remaining: 2.02s
# 44:	learn: 0.8940270	test: 0.6771654	best: 0.7022901 (0)	total: 764ms	remaining: 2s
# 45:	learn: 0.9034749	test: 0.6771654	best: 0.7022901 (0)	total: 779ms	remaining: 1.98s
# 46:	learn: 0.8996139	test: 0.6771654	best: 0.7022901 (0)	total: 797ms	remaining: 1.97s
# 47:	learn: 0.9013540	test: 0.6666667	best: 0.7022901 (0)	total: 816ms	remaining: 1.95s
# 48:	learn: 0.9069767	test: 0.6771654	best: 0.7022901 (0)	total: 834ms	remaining: 1.94s
# 49:	learn: 0.9031008	test: 0.6666667	best: 0.7022901 (0)	total: 851ms	remaining: 1.92s
# 50:	learn: 0.9031008	test: 0.6666667	best: 0.7022901 (0)	total: 869ms	remaining: 1.91s
# 51:	learn: 0.9031008	test: 0.6666667	best: 0.7022901 (0)	total: 887ms	remaining: 1.89s
# 52:	learn: 0.9013540	test: 0.6666667	best: 0.7022901 (0)	total: 904ms	remaining: 1.88s
# 53:	learn: 0.9052224	test: 0.6771654	best: 0.7022901 (0)	total: 921ms	remaining: 1.86s
# 54:	learn: 0.9090909	test: 0.6771654	best: 0.7022901 (0)	total: 940ms	remaining: 1.85s
# 55:	learn: 0.9090909	test: 0.6771654	best: 0.7022901 (0)	total: 968ms	remaining: 1.85s
# 56:	learn: 0.9111969	test: 0.6771654	best: 0.7022901 (0)	total: 1s	remaining: 1.86s
# 57:	learn: 0.9153846	test: 0.6718750	best: 0.7022901 (0)	total: 1.03s	remaining: 1.86s
# 58:	learn: 0.9153846	test: 0.6771654	best: 0.7022901 (0)	total: 1.05s	remaining: 1.86s
# 59:	learn: 0.9174664	test: 0.6771654	best: 0.7022901 (0)	total: 1.08s	remaining: 1.85s
# 60:	learn: 0.9174664	test: 0.6718750	best: 0.7022901 (0)	total: 1.1s	remaining: 1.83s
# 61:	learn: 0.9174664	test: 0.6718750	best: 0.7022901 (0)	total: 1.12s	remaining: 1.82s
# 62:	learn: 0.9174664	test: 0.6718750	best: 0.7022901 (0)	total: 1.14s	remaining: 1.81s
# 63:	learn: 0.9174664	test: 0.6718750	best: 0.7022901 (0)	total: 1.16s	remaining: 1.79s
# 64:	learn: 0.9174664	test: 0.6666667	best: 0.7022901 (0)	total: 1.17s	remaining: 1.77s
# 65:	learn: 0.9192308	test: 0.6718750	best: 0.7022901 (0)	total: 1.19s	remaining: 1.75s
# 66:	learn: 0.9210019	test: 0.6666667	best: 0.7022901 (0)	total: 1.21s	remaining: 1.73s
# 67:	learn: 0.9210019	test: 0.6666667	best: 0.7022901 (0)	total: 1.23s	remaining: 1.71s
# 68:	learn: 0.9210019	test: 0.6718750	best: 0.7022901 (0)	total: 1.24s	remaining: 1.69s
# 69:	learn: 0.9227799	test: 0.6718750	best: 0.7022901 (0)	total: 1.26s	remaining: 1.67s
# 70:	learn: 0.9227799	test: 0.6666667	best: 0.7022901 (0)	total: 1.27s	remaining: 1.65s
# 71:	learn: 0.9269231	test: 0.6666667	best: 0.7022901 (0)	total: 1.29s	remaining: 1.63s
# 72:	learn: 0.9269231	test: 0.6718750	best: 0.7022901 (0)	total: 1.3s	remaining: 1.61s
# 73:	learn: 0.9269231	test: 0.6718750	best: 0.7022901 (0)	total: 1.32s	remaining: 1.58s
# 74:	learn: 0.9289827	test: 0.6718750	best: 0.7022901 (0)	total: 1.34s	remaining: 1.57s
# 75:	learn: 0.9310345	test: 0.6718750	best: 0.7022901 (0)	total: 1.36s	remaining: 1.56s
# 76:	learn: 0.9330784	test: 0.6821705	best: 0.7022901 (0)	total: 1.39s	remaining: 1.55s
# 77:	learn: 0.9289827	test: 0.6718750	best: 0.7022901 (0)	total: 1.4s	remaining: 1.53s
# 78:	learn: 0.9348659	test: 0.6614173	best: 0.7022901 (0)	total: 1.42s	remaining: 1.51s
# 79:	learn: 0.9348659	test: 0.6718750	best: 0.7022901 (0)	total: 1.43s	remaining: 1.49s
# 80:	learn: 0.9348659	test: 0.6718750	best: 0.7022901 (0)	total: 1.45s	remaining: 1.47s
# 81:	learn: 0.9348659	test: 0.6666667	best: 0.7022901 (0)	total: 1.47s	remaining: 1.45s
# 82:	learn: 0.9369025	test: 0.6666667	best: 0.7022901 (0)	total: 1.49s	remaining: 1.43s
# 83:	learn: 0.9389313	test: 0.6666667	best: 0.7022901 (0)	total: 1.5s	remaining: 1.41s
# 84:	learn: 0.9407266	test: 0.6666667	best: 0.7022901 (0)	total: 1.52s	remaining: 1.39s
# 85:	learn: 0.9389313	test: 0.6564885	best: 0.7022901 (0)	total: 1.53s	remaining: 1.37s
# 86:	learn: 0.9389313	test: 0.6564885	best: 0.7022901 (0)	total: 1.55s	remaining: 1.36s
# 87:	learn: 0.9389313	test: 0.6564885	best: 0.7022901 (0)	total: 1.57s	remaining: 1.34s
# 88:	learn: 0.9389313	test: 0.6564885	best: 0.7022901 (0)	total: 1.59s	remaining: 1.32s
# 89:	learn: 0.9427481	test: 0.6615385	best: 0.7022901 (0)	total: 1.6s	remaining: 1.3s
# 90:	learn: 0.9389313	test: 0.6666667	best: 0.7022901 (0)	total: 1.62s	remaining: 1.28s
# 91:	learn: 0.9407266	test: 0.6562500	best: 0.7022901 (0)	total: 1.63s	remaining: 1.26s
# 92:	learn: 0.9427481	test: 0.6562500	best: 0.7022901 (0)	total: 1.65s	remaining: 1.24s
# 93:	learn: 0.9467681	test: 0.6511628	best: 0.7022901 (0)	total: 1.66s	remaining: 1.22s
# 94:	learn: 0.9467681	test: 0.6614173	best: 0.7022901 (0)	total: 1.68s	remaining: 1.2s
# 95:	learn: 0.9487666	test: 0.6614173	best: 0.7022901 (0)	total: 1.7s	remaining: 1.18s
# 96:	learn: 0.9487666	test: 0.6562500	best: 0.7022901 (0)	total: 1.71s	remaining: 1.16s
# 97:	learn: 0.9487666	test: 0.6511628	best: 0.7022901 (0)	total: 1.73s	remaining: 1.15s
# 98:	learn: 0.9487666	test: 0.6511628	best: 0.7022901 (0)	total: 1.75s	remaining: 1.13s
# 99:	learn: 0.9487666	test: 0.6511628	best: 0.7022901 (0)	total: 1.76s	remaining: 1.11s
# 100:	learn: 0.9469697	test: 0.6511628	best: 0.7022901 (0)	total: 1.78s	remaining: 1.09s
# 101:	learn: 0.9487666	test: 0.6562500	best: 0.7022901 (0)	total: 1.79s	remaining: 1.07s
# 102:	learn: 0.9487666	test: 0.6562500	best: 0.7022901 (0)	total: 1.81s	remaining: 1.05s
# 103:	learn: 0.9487666	test: 0.6562500	best: 0.7022901 (0)	total: 1.83s	remaining: 1.04s
# 104:	learn: 0.9487666	test: 0.6511628	best: 0.7022901 (0)	total: 1.84s	remaining: 1.02s
# 105:	learn: 0.9487666	test: 0.6615385	best: 0.7022901 (0)	total: 1.86s	remaining: 999ms
# 106:	learn: 0.9507576	test: 0.6615385	best: 0.7022901 (0)	total: 1.87s	remaining: 981ms
# 107:	learn: 0.9507576	test: 0.6564885	best: 0.7022901 (0)	total: 1.89s	remaining: 962ms
# 108:	learn: 0.9507576	test: 0.6564885	best: 0.7022901 (0)	total: 1.91s	remaining: 944ms
# 109:	learn: 0.9507576	test: 0.6564885	best: 0.7022901 (0)	total: 1.92s	remaining: 926ms
# 110:	learn: 0.9507576	test: 0.6461538	best: 0.7022901 (0)	total: 1.94s	remaining: 907ms
# 111:	learn: 0.9507576	test: 0.6461538	best: 0.7022901 (0)	total: 1.95s	remaining: 889ms
# 112:	learn: 0.9527410	test: 0.6461538	best: 0.7022901 (0)	total: 1.98s	remaining: 874ms
# 113:	learn: 0.9547170	test: 0.6511628	best: 0.7022901 (0)	total: 2s	remaining: 858ms
# 114:	learn: 0.9547170	test: 0.6511628	best: 0.7022901 (0)	total: 2.01s	remaining: 840ms
# 115:	learn: 0.9547170	test: 0.6511628	best: 0.7022901 (0)	total: 2.03s	remaining: 821ms
# 116:	learn: 0.9547170	test: 0.6511628	best: 0.7022901 (0)	total: 2.04s	remaining: 803ms
# 117:	learn: 0.9547170	test: 0.6511628	best: 0.7022901 (0)	total: 2.06s	remaining: 784ms
# 118:	learn: 0.9547170	test: 0.6615385	best: 0.7022901 (0)	total: 2.07s	remaining: 766ms
# 119:	learn: 0.9547170	test: 0.6564885	best: 0.7022901 (0)	total: 2.09s	remaining: 748ms
# 120:	learn: 0.9547170	test: 0.6564885	best: 0.7022901 (0)	total: 2.1s	remaining: 730ms
# 121:	learn: 0.9547170	test: 0.6461538	best: 0.7022901 (0)	total: 2.12s	remaining: 712ms
# 122:	learn: 0.9547170	test: 0.6461538	best: 0.7022901 (0)	total: 2.13s	remaining: 694ms
# 123:	learn: 0.9547170	test: 0.6461538	best: 0.7022901 (0)	total: 2.15s	remaining: 677ms
# 124:	learn: 0.9547170	test: 0.6461538	best: 0.7022901 (0)	total: 2.17s	remaining: 659ms
# 125:	learn: 0.9547170	test: 0.6461538	best: 0.7022901 (0)	total: 2.19s	remaining: 643ms
# 154:	learn: 0.9700375	test: 0.6666667	best: 0.7022901 (0)	total: 2.68s	remaining: 138ms
# 155:	learn: 0.9700375	test: 0.6615385	best: 0.7022901 (0)	total: 2.69s	remaining: 121ms
# 156:	learn: 0.9700375	test: 0.6615385	best: 0.7022901 (0)	total: 2.71s	remaining: 104ms
# 157:	learn: 0.9700375	test: 0.6718750	best: 0.7022901 (0)	total: 2.73s	remaining: 86.3ms
# 158:	learn: 0.9700375	test: 0.6718750	best: 0.7022901 (0)	total: 2.75s	remaining: 69.1ms
# 159:	learn: 0.9700375	test: 0.6718750	best: 0.7022901 (0)	total: 2.77s	remaining: 51.9ms
# 160:	learn: 0.9700375	test: 0.6666667	best: 0.7022901 (0)	total: 2.79s	remaining: 34.6ms
# 161:	learn: 0.9700375	test: 0.6666667	best: 0.7022901 (0)	total: 2.8s	remaining: 17.3ms
# 162:	learn: 0.9700375	test: 0.6666667	best: 0.7022901 (0)	total: 2.82s	remaining: 0us
#
# bestTest = 0.7022900763
# bestIteration = 0
#
# Training on fold [2/5]
# 0:	learn: 0.7639155	test: 0.6969697	best: 0.6969697 (0)	total: 18.4ms	remaining: 2.98s
# 1:	learn: 0.7715931	test: 0.6717557	best: 0.6969697 (0)	total: 33.2ms	remaining: 2.67s
# 2:	learn: 0.7707129	test: 0.6821705	best: 0.6969697 (0)	total: 46.9ms	remaining: 2.5s
# 3:	learn: 0.7730769	test: 0.6821705	best: 0.6969697 (0)	total: 63.2ms	remaining: 2.51s
# 4:	learn: 0.7844660	test: 0.6829268	best: 0.6969697 (0)	total: 79.7ms	remaining: 2.52s
# 5:	learn: 0.7844660	test: 0.6829268	best: 0.6969697 (0)	total: 95.2ms	remaining: 2.49s
# 6:	learn: 0.7852998	test: 0.6829268	best: 0.6969697 (0)	total: 111ms	remaining: 2.48s
# 7:	learn: 0.7868217	test: 0.6829268	best: 0.6969697 (0)	total: 126ms	remaining: 2.45s
# 8:	learn: 0.7868217	test: 0.6829268	best: 0.6969697 (0)	total: 144ms	remaining: 2.46s
# 9:	learn: 0.7944664	test: 0.6890756	best: 0.6969697 (0)	total: 169ms	remaining: 2.58s
# 10:	learn: 0.8183633	test: 0.7008547	best: 0.7008547 (10)	total: 189ms	remaining: 2.61s
# 11:	learn: 0.8198020	test: 0.7166667	best: 0.7166667 (11)	total: 206ms	remaining: 2.59s
# 12:	learn: 0.8190855	test: 0.7226891	best: 0.7226891 (12)	total: 222ms	remaining: 2.56s
# 13:	learn: 0.8228346	test: 0.7226891	best: 0.7226891 (12)	total: 238ms	remaining: 2.53s
# 14:	learn: 0.8297456	test: 0.7272727	best: 0.7272727 (14)	total: 253ms	remaining: 2.5s
# 15:	learn: 0.8443580	test: 0.7272727	best: 0.7272727 (14)	total: 268ms	remaining: 2.46s
# 16:	learn: 0.8571429	test: 0.7107438	best: 0.7272727 (14)	total: 285ms	remaining: 2.45s
# 17:	learn: 0.8598848	test: 0.7154472	best: 0.7272727 (14)	total: 301ms	remaining: 2.42s
# 18:	learn: 0.8582524	test: 0.7096774	best: 0.7272727 (14)	total: 317ms	remaining: 2.4s
# 19:	learn: 0.8571429	test: 0.7049180	best: 0.7272727 (14)	total: 337ms	remaining: 2.41s
# 20:	learn: 0.8532819	test: 0.7154472	best: 0.7272727 (14)	total: 353ms	remaining: 2.39s
# 21:	learn: 0.8576923	test: 0.7107438	best: 0.7272727 (14)	total: 373ms	remaining: 2.39s
# 22:	learn: 0.8615385	test: 0.7040000	best: 0.7272727 (14)	total: 391ms	remaining: 2.38s
# 23:	learn: 0.8615385	test: 0.7142857	best: 0.7272727 (14)	total: 408ms	remaining: 2.36s
# 24:	learn: 0.8598848	test: 0.7096774	best: 0.7272727 (14)	total: 423ms	remaining: 2.34s
# 25:	learn: 0.8593156	test: 0.7154472	best: 0.7272727 (14)	total: 438ms	remaining: 2.31s
# 26:	learn: 0.8571429	test: 0.7154472	best: 0.7272727 (14)	total: 453ms	remaining: 2.28s
# 27:	learn: 0.8609524	test: 0.7096774	best: 0.7272727 (14)	total: 468ms	remaining: 2.25s
# 28:	learn: 0.8625954	test: 0.7096774	best: 0.7272727 (14)	total: 483ms	remaining: 2.23s
# 29:	learn: 0.8631179	test: 0.7154472	best: 0.7272727 (14)	total: 499ms	remaining: 2.21s
# 30:	learn: 0.8647619	test: 0.7040000	best: 0.7272727 (14)	total: 515ms	remaining: 2.19s
# 31:	learn: 0.8690702	test: 0.7040000	best: 0.7272727 (14)	total: 531ms	remaining: 2.17s
# 32:	learn: 0.8690702	test: 0.7040000	best: 0.7272727 (14)	total: 551ms	remaining: 2.17s
# 33:	learn: 0.8728653	test: 0.7142857	best: 0.7272727 (14)	total: 571ms	remaining: 2.16s
# 34:	learn: 0.8690702	test: 0.7142857	best: 0.7272727 (14)	total: 595ms	remaining: 2.17s
# 35:	learn: 0.8680688	test: 0.7040000	best: 0.7272727 (14)	total: 616ms	remaining: 2.17s
# 36:	learn: 0.8702290	test: 0.7040000	best: 0.7272727 (14)	total: 635ms	remaining: 2.16s
# 37:	learn: 0.8702290	test: 0.7142857	best: 0.7272727 (14)	total: 654ms	remaining: 2.15s
# 38:	learn: 0.8702290	test: 0.7301587	best: 0.7301587 (38)	total: 672ms	remaining: 2.13s
# 39:	learn: 0.8740458	test: 0.7301587	best: 0.7301587 (38)	total: 690ms	remaining: 2.12s
# 40:	learn: 0.8761905	test: 0.7301587	best: 0.7301587 (38)	total: 707ms	remaining: 2.1s
# 41:	learn: 0.8761905	test: 0.7301587	best: 0.7301587 (38)	total: 722ms	remaining: 2.08s
# 42:	learn: 0.8761905	test: 0.7360000	best: 0.7360000 (42)	total: 737ms	remaining: 2.06s
# 43:	learn: 0.8783270	test: 0.7401575	best: 0.7401575 (43)	total: 752ms	remaining: 2.03s
# 44:	learn: 0.8783270	test: 0.7343750	best: 0.7401575 (43)	total: 768ms	remaining: 2.01s
# 45:	learn: 0.8761905	test: 0.7244094	best: 0.7401575 (43)	total: 783ms	remaining: 1.99s
# 46:	learn: 0.8783270	test: 0.7301587	best: 0.7401575 (43)	total: 804ms	remaining: 1.99s
# 47:	learn: 0.8761905	test: 0.7301587	best: 0.7401575 (43)	total: 821ms	remaining: 1.97s
# 48:	learn: 0.8761905	test: 0.7301587	best: 0.7401575 (43)	total: 836ms	remaining: 1.94s
# 49:	learn: 0.8783270	test: 0.7200000	best: 0.7401575 (43)	total: 852ms	remaining: 1.93s
# 50:	learn: 0.8783270	test: 0.7301587	best: 0.7401575 (43)	total: 867ms	remaining: 1.9s
# 51:	learn: 0.8761905	test: 0.7301587	best: 0.7401575 (43)	total: 882ms	remaining: 1.88s
# 52:	learn: 0.8761905	test: 0.7301587	best: 0.7401575 (43)	total: 898ms	remaining: 1.86s
# 53:	learn: 0.8816794	test: 0.7301587	best: 0.7401575 (43)	total: 915ms	remaining: 1.85s
# 54:	learn: 0.8816794	test: 0.7301587	best: 0.7401575 (43)	total: 930ms	remaining: 1.82s
# 55:	learn: 0.8816794	test: 0.7301587	best: 0.7401575 (43)	total: 945ms	remaining: 1.8s
# 56:	learn: 0.8816794	test: 0.7301587	best: 0.7401575 (43)	total: 960ms	remaining: 1.79s
# 57:	learn: 0.8833652	test: 0.7419355	best: 0.7419355 (57)	total: 976ms	remaining: 1.77s
# 58:	learn: 0.8795411	test: 0.7360000	best: 0.7419355 (57)	total: 995ms	remaining: 1.75s
# 59:	learn: 0.8816794	test: 0.7360000	best: 0.7419355 (57)	total: 1.01s	remaining: 1.74s
# 60:	learn: 0.8838095	test: 0.7360000	best: 0.7419355 (57)	total: 1.03s	remaining: 1.72s
# 61:	learn: 0.8821293	test: 0.7360000	best: 0.7419355 (57)	total: 1.05s	remaining: 1.7s
# 62:	learn: 0.8854962	test: 0.7360000	best: 0.7419355 (57)	total: 1.06s	remaining: 1.69s
# 63:	learn: 0.8876190	test: 0.7360000	best: 0.7419355 (57)	total: 1.08s	remaining: 1.67s
# 64:	learn: 0.8939394	test: 0.7360000	best: 0.7419355 (57)	total: 1.1s	remaining: 1.66s
# 65:	learn: 0.8973384	test: 0.7360000	best: 0.7419355 (57)	total: 1.12s	remaining: 1.65s
# 66:	learn: 0.8973384	test: 0.7360000	best: 0.7419355 (57)	total: 1.15s	remaining: 1.65s
# 67:	learn: 0.8973384	test: 0.7360000	best: 0.7419355 (57)	total: 1.18s	remaining: 1.65s
# 68:	learn: 0.8994307	test: 0.7360000	best: 0.7419355 (57)	total: 1.2s	remaining: 1.64s
# 69:	learn: 0.9015152	test: 0.7360000	best: 0.7419355 (57)	total: 1.23s	remaining: 1.63s
# 70:	learn: 0.9032258	test: 0.7360000	best: 0.7419355 (57)	total: 1.25s	remaining: 1.62s
# 71:	learn: 0.9032258	test: 0.7559055	best: 0.7559055 (71)	total: 1.27s	remaining: 1.6s
# 72:	learn: 0.9049430	test: 0.7656250	best: 0.7656250 (72)	total: 1.28s	remaining: 1.58s
# 73:	learn: 0.9070209	test: 0.7559055	best: 0.7656250 (72)	total: 1.3s	remaining: 1.57s
# 74:	learn: 0.9104762	test: 0.7360000	best: 0.7656250 (72)	total: 1.32s	remaining: 1.55s
# 75:	learn: 0.9104762	test: 0.7460317	best: 0.7656250 (72)	total: 1.33s	remaining: 1.53s
# 76:	learn: 0.9125475	test: 0.7460317	best: 0.7656250 (72)	total: 1.35s	remaining: 1.51s
# 77:	learn: 0.9125475	test: 0.7559055	best: 0.7656250 (72)	total: 1.37s	remaining: 1.49s
# 78:	learn: 0.9125475	test: 0.7559055	best: 0.7656250 (72)	total: 1.38s	remaining: 1.47s
# 79:	learn: 0.9160305	test: 0.7460317	best: 0.7656250 (72)	total: 1.4s	remaining: 1.45s
# 80:	learn: 0.9142857	test: 0.7559055	best: 0.7656250 (72)	total: 1.41s	remaining: 1.43s
# 81:	learn: 0.9142857	test: 0.7559055	best: 0.7656250 (72)	total: 1.43s	remaining: 1.41s
# 82:	learn: 0.9142857	test: 0.7460317	best: 0.7656250 (72)	total: 1.46s	remaining: 1.4s
# 83:	learn: 0.9142857	test: 0.7460317	best: 0.7656250 (72)	total: 1.47s	remaining: 1.39s
# 84:	learn: 0.9163498	test: 0.7460317	best: 0.7656250 (72)	total: 1.49s	remaining: 1.36s
# 85:	learn: 0.9142857	test: 0.7520000	best: 0.7656250 (72)	total: 1.5s	remaining: 1.35s
# 86:	learn: 0.9184061	test: 0.7460317	best: 0.7656250 (72)	total: 1.52s	remaining: 1.33s
# 87:	learn: 0.9201521	test: 0.7460317	best: 0.7656250 (72)	total: 1.53s	remaining: 1.31s
# 88:	learn: 0.9280303	test: 0.7460317	best: 0.7656250 (72)	total: 1.55s	remaining: 1.29s
# 89:	learn: 0.9283019	test: 0.7460317	best: 0.7656250 (72)	total: 1.56s	remaining: 1.27s
# 90:	learn: 0.9283019	test: 0.7460317	best: 0.7656250 (72)	total: 1.58s	remaining: 1.25s
# 91:	learn: 0.9283019	test: 0.7460317	best: 0.7656250 (72)	total: 1.59s	remaining: 1.23s
# 92:	learn: 0.9318182	test: 0.7460317	best: 0.7656250 (72)	total: 1.61s	remaining: 1.21s
# 93:	learn: 0.9283019	test: 0.7401575	best: 0.7656250 (72)	total: 1.63s	remaining: 1.2s
# 94:	learn: 0.9335863	test: 0.7401575	best: 0.7656250 (72)	total: 1.65s	remaining: 1.18s
# 95:	learn: 0.9335863	test: 0.7401575	best: 0.7656250 (72)	total: 1.67s	remaining: 1.16s
# 96:	learn: 0.9335863	test: 0.7301587	best: 0.7656250 (72)	total: 1.68s	remaining: 1.14s
# 97:	learn: 0.9318182	test: 0.7301587	best: 0.7656250 (72)	total: 1.7s	remaining: 1.13s
# 98:	learn: 0.9318182	test: 0.7244094	best: 0.7656250 (72)	total: 1.71s	remaining: 1.11s
# 99:	learn: 0.9335863	test: 0.7244094	best: 0.7656250 (72)	total: 1.73s	remaining: 1.09s
# 100:	learn: 0.9356061	test: 0.7187500	best: 0.7656250 (72)	total: 1.74s	remaining: 1.07s
# 101:	learn: 0.9376181	test: 0.7244094	best: 0.7656250 (72)	total: 1.76s	remaining: 1.05s
# ...
# 145:	learn: 0.9511278	test: 0.7938931	best: 0.8208955 (60)	total: 2.47s	remaining: 287ms
# 146:	learn: 0.9511278	test: 0.7938931	best: 0.8208955 (60)	total: 2.48s	remaining: 270ms
# 147:	learn: 0.9532710	test: 0.7938931	best: 0.8208955 (60)	total: 2.5s	remaining: 253ms
# 148:	learn: 0.9532710	test: 0.7938931	best: 0.8208955 (60)	total: 2.51s	remaining: 236ms
# 149:	learn: 0.9532710	test: 0.7938931	best: 0.8208955 (60)	total: 2.53s	remaining: 220ms
# 150:	learn: 0.9532710	test: 0.7938931	best: 0.8208955 (60)	total: 2.55s	remaining: 203ms
# 151:	learn: 0.9513109	test: 0.7938931	best: 0.8208955 (60)	total: 2.57s	remaining: 186ms
# 152:	learn: 0.9532710	test: 0.8030303	best: 0.8208955 (60)	total: 2.58s	remaining: 169ms
# 153:	learn: 0.9532710	test: 0.8030303	best: 0.8208955 (60)	total: 2.6s	remaining: 152ms
# 154:	learn: 0.9532710	test: 0.8030303	best: 0.8208955 (60)	total: 2.61s	remaining: 135ms
# 155:	learn: 0.9532710	test: 0.8030303	best: 0.8208955 (60)	total: 2.63s	remaining: 118ms
# 156:	learn: 0.9532710	test: 0.8030303	best: 0.8208955 (60)	total: 2.64s	remaining: 101ms
# 157:	learn: 0.9552239	test: 0.8030303	best: 0.8208955 (60)	total: 2.66s	remaining: 84.1ms
# 158:	learn: 0.9552239	test: 0.8030303	best: 0.8208955 (60)	total: 2.67s	remaining: 67.2ms
# 159:	learn: 0.9552239	test: 0.7938931	best: 0.8208955 (60)	total: 2.69s	remaining: 50.4ms
# 160:	learn: 0.9552239	test: 0.7938931	best: 0.8208955 (60)	total: 2.7s	remaining: 33.6ms
# 161:	learn: 0.9552239	test: 0.7938931	best: 0.8208955 (60)	total: 2.72s	remaining: 16.8ms
# 162:	learn: 0.9571695	test: 0.7938931	best: 0.8208955 (60)	total: 2.74s	remaining: 0us
#
# bestTest = 0.8208955224
# bestIteration = 60
#
# Training on fold [4/5]
# 0:	learn: 0.7490494	test: 0.7343750	best: 0.7343750 (0)	total: 16.3ms	remaining: 2.65s
# 1:	learn: 0.7620890	test: 0.7401575	best: 0.7401575 (1)	total: 28.7ms	remaining: 2.31s
# 2:	learn: 0.7641326	test: 0.7401575	best: 0.7401575 (1)	total: 44.1ms	remaining: 2.35s
# 3:	learn: 0.7656250	test: 0.7401575	best: 0.7401575 (1)	total: 59.2ms	remaining: 2.35s
# 4:	learn: 0.7710372	test: 0.7401575	best: 0.7401575 (1)	total: 74ms	remaining: 2.34s
# 5:	learn: 0.7734375	test: 0.7401575	best: 0.7401575 (1)	total: 90ms	remaining: 2.36s
# 6:	learn: 0.7890625	test: 0.7401575	best: 0.7401575 (1)	total: 106ms	remaining: 2.36s
# 7:	learn: 0.7976190	test: 0.7540984	best: 0.7540984 (7)	total: 121ms	remaining: 2.34s
# 8:	learn: 0.7953216	test: 0.7401575	best: 0.7540984 (7)	total: 137ms	remaining: 2.35s
# 9:	learn: 0.7976190	test: 0.7360000	best: 0.7540984 (7)	total: 154ms	remaining: 2.35s
# 10:	learn: 0.8023715	test: 0.7301587	best: 0.7540984 (7)	total: 176ms	remaining: 2.43s
# 11:	learn: 0.8070866	test: 0.7244094	best: 0.7540984 (7)	total: 192ms	remaining: 2.42s
# 12:	learn: 0.8233010	test: 0.7244094	best: 0.7540984 (7)	total: 208ms	remaining: 2.4s
# 13:	learn: 0.8281250	test: 0.7301587	best: 0.7540984 (7)	total: 223ms	remaining: 2.37s
# 14:	learn: 0.8493151	test: 0.7244094	best: 0.7540984 (7)	total: 238ms	remaining: 2.35s
# 15:	learn: 0.8515625	test: 0.7244094	best: 0.7540984 (7)	total: 253ms	remaining: 2.33s
# 16:	learn: 0.8498024	test: 0.7187500	best: 0.7540984 (7)	total: 268ms	remaining: 2.3s
# 17:	learn: 0.8508946	test: 0.7244094	best: 0.7540984 (7)	total: 283ms	remaining: 2.28s
# 18:	learn: 0.8475248	test: 0.7301587	best: 0.7540984 (7)	total: 299ms	remaining: 2.26s
# 19:	learn: 0.8543307	test: 0.7301587	best: 0.7540984 (7)	total: 315ms	remaining: 2.25s
# 20:	learn: 0.8593750	test: 0.7258065	best: 0.7540984 (7)	total: 330ms	remaining: 2.23s
# 21:	learn: 0.8615984	test: 0.7258065	best: 0.7540984 (7)	total: 344ms	remaining: 2.21s
# 22:	learn: 0.8677043	test: 0.7258065	best: 0.7540984 (7)	total: 360ms	remaining: 2.19s
# 23:	learn: 0.8720930	test: 0.7258065	best: 0.7540984 (7)	total: 377ms	remaining: 2.18s
# 24:	learn: 0.8764479	test: 0.7086614	best: 0.7540984 (7)	total: 393ms	remaining: 2.17s
# 25:	learn: 0.8781431	test: 0.7187500	best: 0.7540984 (7)	total: 408ms	remaining: 2.15s
# 26:	learn: 0.8837209	test: 0.7187500	best: 0.7540984 (7)	total: 424ms	remaining: 2.13s
# 27:	learn: 0.8815534	test: 0.7187500	best: 0.7540984 (7)	total: 440ms	remaining: 2.12s
# 28:	learn: 0.8841699	test: 0.7131783	best: 0.7540984 (7)	total: 456ms	remaining: 2.11s
# 29:	learn: 0.8829175	test: 0.6929134	best: 0.7540984 (7)	total: 472ms	remaining: 2.09s
# 30:	learn: 0.8850575	test: 0.6929134	best: 0.7540984 (7)	total: 487ms	remaining: 2.07s
# 31:	learn: 0.8871893	test: 0.6929134	best: 0.7540984 (7)	total: 502ms	remaining: 2.06s
# 32:	learn: 0.8871893	test: 0.7086614	best: 0.7540984 (7)	total: 517ms	remaining: 2.04s
# 33:	learn: 0.8931298	test: 0.7086614	best: 0.7540984 (7)	total: 532ms	remaining: 2.02s
# 34:	learn: 0.8905950	test: 0.7286822	best: 0.7540984 (7)	total: 546ms	remaining: 2s
# 35:	learn: 0.8948375	test: 0.7286822	best: 0.7540984 (7)	total: 561ms	remaining: 1.98s
# 36:	learn: 0.8923077	test: 0.7384615	best: 0.7540984 (7)	total: 578ms	remaining: 1.97s
# 37:	learn: 0.8923077	test: 0.7286822	best: 0.7540984 (7)	total: 601ms	remaining: 1.98s
# 38:	learn: 0.8905950	test: 0.7441860	best: 0.7540984 (7)	total: 617ms	remaining: 1.96s
# 39:	learn: 0.8905950	test: 0.7441860	best: 0.7540984 (7)	total: 632ms	remaining: 1.94s
# 40:	learn: 0.8961538	test: 0.7244094	best: 0.7540984 (7)	total: 647ms	remaining: 1.92s
# 41:	learn: 0.8923077	test: 0.7343750	best: 0.7540984 (7)	total: 663ms	remaining: 1.91s
# 42:	learn: 0.8901734	test: 0.7040000	best: 0.7540984 (7)	total: 680ms	remaining: 1.9s
# 43:	learn: 0.8901734	test: 0.7040000	best: 0.7540984 (7)	total: 695ms	remaining: 1.88s
# 44:	learn: 0.8961538	test: 0.7040000	best: 0.7540984 (7)	total: 712ms	remaining: 1.86s
# 45:	learn: 0.8940270	test: 0.7040000	best: 0.7540984 (7)	total: 728ms	remaining: 1.85s
# 46:	learn: 0.9003831	test: 0.7343750	best: 0.7540984 (7)	total: 743ms	remaining: 1.83s
# 47:	learn: 0.9003831	test: 0.7343750	best: 0.7540984 (7)	total: 760ms	remaining: 1.82s
# 48:	learn: 0.9038462	test: 0.7244094	best: 0.7540984 (7)	total: 777ms	remaining: 1.81s
# 49:	learn: 0.9021113	test: 0.7244094	best: 0.7540984 (7)	total: 792ms	remaining: 1.79s
# 50:	learn: 0.9045802	test: 0.7244094	best: 0.7540984 (7)	total: 809ms	remaining: 1.78s
# 51:	learn: 0.9042146	test: 0.7343750	best: 0.7540984 (7)	total: 827ms	remaining: 1.76s
# 52:	learn: 0.9042146	test: 0.7343750	best: 0.7540984 (7)	total: 842ms	remaining: 1.75s
# 53:	learn: 0.9042146	test: 0.7343750	best: 0.7540984 (7)	total: 858ms	remaining: 1.73s
# 54:	learn: 0.9080460	test: 0.7040000	best: 0.7540984 (7)	total: 874ms	remaining: 1.72s
# 55:	learn: 0.9080460	test: 0.7040000	best: 0.7540984 (7)	total: 889ms	remaining: 1.7s
# 56:	learn: 0.9080460	test: 0.7040000	best: 0.7540984 (7)	total: 903ms	remaining: 1.68s
# 57:	learn: 0.9059501	test: 0.7040000	best: 0.7540984 (7)	total: 918ms	remaining: 1.66s
# 58:	learn: 0.9055877	test: 0.7096774	best: 0.7540984 (7)	total: 934ms	remaining: 1.65s
# 59:	learn: 0.9055877	test: 0.7154472	best: 0.7540984 (7)	total: 949ms	remaining: 1.63s
# 60:	learn: 0.9076923	test: 0.7096774	best: 0.7540984 (7)	total: 965ms	remaining: 1.61s
# 61:	learn: 0.9115385	test: 0.7154472	best: 0.7540984 (7)	total: 981ms	remaining: 1.6s
# 62:	learn: 0.9115385	test: 0.7154472	best: 0.7540984 (7)	total: 1s	remaining: 1.59s
# 63:	learn: 0.9136276	test: 0.7096774	best: 0.7540984 (7)	total: 1.02s	remaining: 1.57s
# 64:	learn: 0.9136276	test: 0.7154472	best: 0.7540984 (7)	total: 1.04s	remaining: 1.56s
# 65:	learn: 0.9174664	test: 0.7258065	best: 0.7540984 (7)	total: 1.05s	remaining: 1.55s
# 66:	learn: 0.9177820	test: 0.7258065	best: 0.7540984 (7)	total: 1.07s	remaining: 1.54s
# 67:	learn: 0.9239544	test: 0.7154472	best: 0.7540984 (7)	total: 1.09s	remaining: 1.53s
# 68:	learn: 0.9219048	test: 0.7096774	best: 0.7540984 (7)	total: 1.12s	remaining: 1.52s
# 69:	learn: 0.9198473	test: 0.7213115	best: 0.7540984 (7)	total: 1.15s	remaining: 1.52s
# 70:	learn: 0.9239544	test: 0.7154472	best: 0.7540984 (7)	total: 1.17s	remaining: 1.52s
# 71:	learn: 0.9259962	test: 0.7272727	best: 0.7540984 (7)	total: 1.19s	remaining: 1.51s
# 72:	learn: 0.9239544	test: 0.7213115	best: 0.7540984 (7)	total: 1.21s	remaining: 1.5s
# 73:	learn: 0.9259962	test: 0.7107438	best: 0.7540984 (7)	total: 1.24s	remaining: 1.49s
# 74:	learn: 0.9259962	test: 0.7213115	best: 0.7540984 (7)	total: 1.26s	remaining: 1.48s
# 75:	learn: 0.9280303	test: 0.7166667	best: 0.7540984 (7)	total: 1.28s	remaining: 1.46s
# 76:	learn: 0.9259962	test: 0.7166667	best: 0.7540984 (7)	total: 1.29s	remaining: 1.44s
# 77:	learn: 0.9303202	test: 0.7272727	best: 0.7540984 (7)	total: 1.31s	remaining: 1.42s
# 78:	learn: 0.9303202	test: 0.7377049	best: 0.7540984 (7)	total: 1.32s	remaining: 1.41s
# 79:	learn: 0.9323308	test: 0.7377049	best: 0.7540984 (7)	total: 1.34s	remaining: 1.39s
# 80:	learn: 0.9363296	test: 0.7377049	best: 0.7540984 (7)	total: 1.35s	remaining: 1.37s
# 81:	learn: 0.9343340	test: 0.7377049	best: 0.7540984 (7)	total: 1.37s	remaining: 1.35s
# 82:	learn: 0.9360902	test: 0.7272727	best: 0.7540984 (7)	total: 1.39s	remaining: 1.33s
# 83:	learn: 0.9380863	test: 0.7213115	best: 0.7540984 (7)	total: 1.4s	remaining: 1.32s
# 84:	learn: 0.9380863	test: 0.7213115	best: 0.7540984 (7)	total: 1.41s	remaining: 1.3s
# 85:	learn: 0.9360902	test: 0.7107438	best: 0.7540984 (7)	total: 1.43s	remaining: 1.28s
# 86:	learn: 0.9340866	test: 0.7107438	best: 0.7540984 (7)	total: 1.45s	remaining: 1.27s
# 87:	learn: 0.9360902	test: 0.7107438	best: 0.7540984 (7)	total: 1.47s	remaining: 1.25s
# 88:	learn: 0.9360902	test: 0.7049180	best: 0.7540984 (7)	total: 1.48s	remaining: 1.23s
# 89:	learn: 0.9360902	test: 0.6991870	best: 0.7540984 (7)	total: 1.5s	remaining: 1.22s
# 90:	learn: 0.9380863	test: 0.6991870	best: 0.7540984 (7)	total: 1.51s	remaining: 1.2s
# 91:	learn: 0.9400749	test: 0.6991870	best: 0.7540984 (7)	total: 1.53s	remaining: 1.18s
# 92:	learn: 0.9418386	test: 0.6991870	best: 0.7540984 (7)	total: 1.54s	remaining: 1.16s
# 93:	learn: 0.9418386	test: 0.7049180	best: 0.7540984 (7)	total: 1.56s	remaining: 1.15s
# 94:	learn: 0.9418386	test: 0.6991870	best: 0.7540984 (7)	total: 1.58s	remaining: 1.13s
# 95:	learn: 0.9418386	test: 0.6935484	best: 0.7540984 (7)	total: 1.59s	remaining: 1.11s
# 96:	learn: 0.9418386	test: 0.6991870	best: 0.7540984 (7)	total: 1.61s	remaining: 1.09s
# 97:	learn: 0.9418386	test: 0.6880000	best: 0.7540984 (7)	total: 1.63s	remaining: 1.08s
# 98:	learn: 0.9416196	test: 0.6991870	best: 0.7540984 (7)	total: 1.64s	remaining: 1.06s
# 99:	learn: 0.9416196	test: 0.6935484	best: 0.7540984 (7)	total: 1.66s	remaining: 1.05s
# 100:	learn: 0.9453861	test: 0.6935484	best: 0.7540984 (7)	total: 1.68s	remaining: 1.03s
# 101:	learn: 0.9453861	test: 0.6880000	best: 0.7540984 (7)	total: 1.69s	remaining: 1.01s
# 102:	learn: 0.9493433	test: 0.6825397	best: 0.7540984 (7)	total: 1.71s	remaining: 996ms
# 103:	learn: 0.9495327	test: 0.6825397	best: 0.7540984 (7)	total: 1.72s	remaining: 978ms
# 104:	learn: 0.9495327	test: 0.6825397	best: 0.7540984 (7)	total: 1.74s	remaining: 961ms
# 105:	learn: 0.9495327	test: 0.6825397	best: 0.7540984 (7)	total: 1.76s	remaining: 944ms
# 106:	learn: 0.9495327	test: 0.6825397	best: 0.7540984 (7)	total: 1.77s	remaining: 929ms
# 107:	learn: 0.9513109	test: 0.6880000	best: 0.7540984 (7)	total: 1.79s	remaining: 912ms
# 108:	learn: 0.9513109	test: 0.6880000	best: 0.7540984 (7)	total: 1.8s	remaining: 894ms
# 109:	learn: 0.9513109	test: 0.6991870	best: 0.7540984 (7)	total: 1.82s	remaining: 877ms
# 110:	learn: 0.9532710	test: 0.6991870	best: 0.7540984 (7)	total: 1.83s	remaining: 860ms
# 111:	learn: 0.9532710	test: 0.6991870	best: 0.7540984 (7)	total: 1.85s	remaining: 842ms
# 112:	learn: 0.9532710	test: 0.6991870	best: 0.7540984 (7)	total: 1.87s	remaining: 826ms
# 113:	learn: 0.9532710	test: 0.6991870	best: 0.7540984 (7)	total: 1.88s	remaining: 810ms
# 114:	learn: 0.9532710	test: 0.6935484	best: 0.7540984 (7)	total: 1.9s	remaining: 793ms
# 115:	learn: 0.9532710	test: 0.6991870	best: 0.7540984 (7)	total: 1.92s	remaining: 776ms
# 116:	learn: 0.9552239	test: 0.6880000	best: 0.7540984 (7)	total: 1.93s	remaining: 759ms
# 117:	learn: 0.9532710	test: 0.6935484	best: 0.7540984 (7)	total: 1.95s	remaining: 742ms
# 118:	learn: 0.9532710	test: 0.6935484	best: 0.7540984 (7)	total: 1.96s	remaining: 726ms
# 119:	learn: 0.9532710	test: 0.6935484	best: 0.7540984 (7)	total: 1.98s	remaining: 709ms
	learn: 0.9628253	test: 0.7154472	best: 0.7540984 (7)	total: 2.46s	remaining: 196ms
# 151:	learn: 0.9628253	test: 0.7154472	best: 0.7540984 (7)	total: 2.48s	remaining: 179ms
# 152:	learn: 0.9628253	test: 0.7154472	best: 0.7540984 (7)	total: 2.49s	remaining: 163ms
# 153:	learn: 0.9628253	test: 0.7154472	best: 0.7540984 (7)	total: 2.51s	remaining: 147ms
# 154:	learn: 0.9628253	test: 0.7154472	best: 0.7540984 (7)	total: 2.53s	remaining: 130ms
# 155:	learn: 0.9628253	test: 0.7154472	best: 0.7540984 (7)	total: 2.54s	remaining: 114ms
# 156:	learn: 0.9628253	test: 0.7154472	best: 0.7540984 (7)	total: 2.56s	remaining: 97.8ms
# 157:	learn: 0.9628253	test: 0.7154472	best: 0.7540984 (7)	total: 2.57s	remaining: 81.4ms
# 158:	learn: 0.9628253	test: 0.7154472	best: 0.7540984 (7)	total: 2.59s	remaining: 65.1ms
# 159:	learn: 0.9628253	test: 0.7258065	best: 0.7540984 (7)	total: 2.6s	remaining: 48.8ms
# 160:	learn: 0.9628253	test: 0.7258065	best: 0.7540984 (7)	total: 2.62s	remaining: 32.5ms
# 161:	learn: 0.9666667	test: 0.7258065	best: 0.7540984 (7)	total: 2.63s	remaining: 16.3ms
# 162:	learn: 0.9666667	test: 0.7258065	best: 0.7540984 (7)	total: 2.65s	remaining: 0us
#
# bestTest = 0.7540983607
# bestIteration = 7

# %% [markdown]
# And get the performance plots:

# %%
import plotly.graph_objects as go

# Create figure
fig = go.Figure()

# Add mean performance line
fig.add_trace(
    go.Scatter(
        x=cv_results["iterations"], y=cv_results["test-F1-mean"], mode="lines", name="Mean F1 Score", line=dict(color="blue")
    )
)

# Add shaded error region
fig.add_trace(
    go.Scatter(
        x=pd.concat([cv_results["iterations"], cv_results["iterations"][::-1]]),
        y=pd.concat([cv_results["test-F1-mean"]+cv_results["test-F1-std"], 
                     cv_results["test-F1-mean"]-cv_results["test-F1-std"]]),
        fill="toself", 
        fillcolor="rgba(0, 0, 255, 0.2)",
        line=dict(color="rgba(255, 255, 255, 0)"),
        showlegend=False
    )
)

# Customize layout
fig.update_layout(
    title="Cross-Validation (N=5) Mean F1 score with Error Bands",
    xaxis_title="Training Steps",
    yaxis_title="Performance Score",
    template="plotly_white",
    yaxis=dict(range=[0.5, 1])
)

fig.show()

fig.write_image(outfolder / "test_f1_v2.png")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 37
#      27 fig.update_layout(
#      28     title="Cross-Validation (N=5) Mean F1 score with Error Bands",
#      29     xaxis_title="Training Steps",
#    (...)     32     yaxis=dict(range=[0.5, 1])
#      33 )
#      35 fig.show()
# ---> 37 fig.write_image(outfolder / "test_f1_v2.png")
#
# File c:\Users\Karolina\Desktop\Studia mgr\Podyplomówka\MLOps\Labs\.venv\Lib\site-packages\plotly\basedatatypes.py:3827, in BaseFigure.write_image(self, *args, **kwargs)
#    3767 """
#    3768 Convert a figure to a static image and write it to a file or writeable
#    3769 object
#    (...)   3823 None
#    3824 """
#    3825 import plotly.io as pio
# -> 3827 return pio.write_image(self, *args, **kwargs)
#
# File c:\Users\Karolina\Desktop\Studia mgr\Podyplomówka\MLOps\Labs\.venv\Lib\site-packages\plotly\io\_kaleido.py:266, in write_image(fig, file, format, scale, width, height, validate, engine)
#     250             raise ValueError(
#     251                 """
#     252 Cannot infer image type from output path '{file}'.
#    (...)    260                 )
#     261             )
#     263     # Request image
#     264     # -------------
#     265     # Do this first so we don't create a file if image conversion fails
# --> 266     img_data = to_image(
#     267         fig,
#     268         format=format,
#     269         scale=scale,
#     270         width=width,
#     271         height=height,
#     272         validate=validate,
#     273         engine=engine,
#     274     )
#     276     # Open file
#     277     # ---------
#     278     if path is None:
#     279         # We previously failed to make sense of `file` as a pathlib object.
#     280         # Attempt to write to `file` as an open file descriptor.
#
# File c:\Users\Karolina\Desktop\Studia mgr\Podyplomówka\MLOps\Labs\.venv\Lib\site-packages\plotly\io\_kaleido.py:143, in to_image(fig, format, width, height, scale, validate, engine)
#     140 # Validate figure
#     141 # ---------------
#     142 fig_dict = validate_coerce_fig_to_dict(fig, validate)
# --> 143 img_bytes = scope.transform(
#     144     fig_dict, format=format, width=width, height=height, scale=scale
#     145 )
#     147 return img_bytes
#
# File c:\Users\Karolina\Desktop\Studia mgr\Podyplomówka\MLOps\Labs\.venv\Lib\site-packages\kaleido\scopes\plotly.py:153, in PlotlyScope.transform(self, figure, format, width, height, scale)
#     142     raise ValueError(
#     143         "Invalid format '{original_format}'.\n"
#     144         "    Supported formats: {supported_formats_str}"
#    (...)    148         )
#     149     )
#     151 # Transform in using _perform_transform rather than superclass so we can access the full
#     152 # response dict, including error codes.
# --> 153 response = self._perform_transform(
#     154     figure, format=format, width=width, height=height, scale=scale
#     155 )
#     157 # Check for export error, later can customize error messages for plotly Python users
#     158 code = response.get("code", 0)
#
# File c:\Users\Karolina\Desktop\Studia mgr\Podyplomówka\MLOps\Labs\.venv\Lib\site-packages\kaleido\scopes\base.py:293, in BaseScope._perform_transform(self, data, **kwargs)
#     284 """
#     285 Transform input data using the current scope, returning dict response with error code
#     286 whether successful or not.
#    (...)    290 :return: Dict of response from Kaleido executable, whether successful or not
#     291 """
#     292 # Ensure that kaleido subprocess is running
# --> 293 self._ensure_kaleido()
#     295 # Perform export
#     296 export_spec = self._json_dumps(dict(kwargs, data=data)).encode('utf-8')
#
# File c:\Users\Karolina\Desktop\Studia mgr\Podyplomówka\MLOps\Labs\.venv\Lib\site-packages\kaleido\scopes\base.py:203, in BaseScope._ensure_kaleido(self)
#     201 if startup_response.get("code", 0) != 0:
#     202     self._proc.wait()
# --> 203     raise ValueError(startup_response.get("message", "Failed to start Kaleido subprocess"))
#
# ValueError: --plotlyjs argument is not a valid URL or file path:

# %%
import plotly.graph_objects as go

# Create figure
fig = go.Figure()

# Add mean performance line
fig.add_trace(
    go.Scatter(
        x=cv_results["iterations"], y=cv_results["test-Logloss-mean"], mode="lines", name="Mean logloss", line=dict(color="blue")
    )
)

# Add shaded error region
fig.add_trace(
    go.Scatter(
        x=pd.concat([cv_results["iterations"], cv_results["iterations"][::-1]]),
        y=pd.concat([cv_results["test-Logloss-mean"]+cv_results["test-Logloss-std"], 
                     cv_results["test-Logloss-mean"]-cv_results["test-Logloss-std"]]),
        fill="toself", 
        fillcolor="rgba(0, 0, 255, 0.2)",
        line=dict(color="rgba(255, 255, 255, 0)"),
        showlegend=False
    )
)

# Customize layout
fig.update_layout(
    title="Cross-Validation (N=5) Mean Logloss with Error Bands",
    xaxis_title="Training Steps",
    yaxis_title="Logloss",
    template="plotly_white"
)

fig.show()

fig.write_image(outfolder / "test_logloss_v2.png")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 36
#      27 fig.update_layout(
#      28     title="Cross-Validation (N=5) Mean Logloss with Error Bands",
#      29     xaxis_title="Training Steps",
#      30     yaxis_title="Logloss",
#      31     template="plotly_white"
#      32 )
#      34 fig.show()
# ---> 36 fig.write_image(outfolder / "test_logloss_v2.png")
#
# File c:\Users\Karolina\Desktop\Studia mgr\Podyplomówka\MLOps\Labs\.venv\Lib\site-packages\plotly\basedatatypes.py:3827, in BaseFigure.write_image(self, *args, **kwargs)
#    3767 """
#    3768 Convert a figure to a static image and write it to a file or writeable
#    3769 object
#    (...)   3823 None
#    3824 """
#    3825 import plotly.io as pio
# -> 3827 return pio.write_image(self, *args, **kwargs)
#
# File c:\Users\Karolina\Desktop\Studia mgr\Podyplomówka\MLOps\Labs\.venv\Lib\site-packages\plotly\io\_kaleido.py:266, in write_image(fig, file, format, scale, width, height, validate, engine)
#     250             raise ValueError(
#     251                 """
#     252 Cannot infer image type from output path '{file}'.
#    (...)    260                 )
#     261             )
#     263     # Request image
#     264     # -------------
#     265     # Do this first so we don't create a file if image conversion fails
# --> 266     img_data = to_image(
#     267         fig,
#     268         format=format,
#     269         scale=scale,
#     270         width=width,
#     271         height=height,
#     272         validate=validate,
#     273         engine=engine,
#     274     )
#     276     # Open file
#     277     # ---------
#     278     if path is None:
#     279         # We previously failed to make sense of `file` as a pathlib object.
#     280         # Attempt to write to `file` as an open file descriptor.
#
# File c:\Users\Karolina\Desktop\Studia mgr\Podyplomówka\MLOps\Labs\.venv\Lib\site-packages\plotly\io\_kaleido.py:143, in to_image(fig, format, width, height, scale, validate, engine)
#     140 # Validate figure
#     141 # ---------------
#     142 fig_dict = validate_coerce_fig_to_dict(fig, validate)
# --> 143 img_bytes = scope.transform(
#     144     fig_dict, format=format, width=width, height=height, scale=scale
#     145 )
#     147 return img_bytes
#
# File c:\Users\Karolina\Desktop\Studia mgr\Podyplomówka\MLOps\Labs\.venv\Lib\site-packages\kaleido\scopes\plotly.py:153, in PlotlyScope.transform(self, figure, format, width, height, scale)
#     142     raise ValueError(
#     143         "Invalid format '{original_format}'.\n"
#     144         "    Supported formats: {supported_formats_str}"
#    (...)    148         )
#     149     )
#     151 # Transform in using _perform_transform rather than superclass so we can access the full
#     152 # response dict, including error codes.
# --> 153 response = self._perform_transform(
#     154     figure, format=format, width=width, height=height, scale=scale
#     155 )
#     157 # Check for export error, later can customize error messages for plotly Python users
#     158 code = response.get("code", 0)
#
# File c:\Users\Karolina\Desktop\Studia mgr\Podyplomówka\MLOps\Labs\.venv\Lib\site-packages\kaleido\scopes\base.py:293, in BaseScope._perform_transform(self, data, **kwargs)
#     284 """
#     285 Transform input data using the current scope, returning dict response with error code
#     286 whether successful or not.
#    (...)    290 :return: Dict of response from Kaleido executable, whether successful or not
#     291 """
#     292 # Ensure that kaleido subprocess is running
# --> 293 self._ensure_kaleido()
#     295 # Perform export
#     296 export_spec = self._json_dumps(dict(kwargs, data=data)).encode('utf-8')
#
# File c:\Users\Karolina\Desktop\Studia mgr\Podyplomówka\MLOps\Labs\.venv\Lib\site-packages\kaleido\scopes\base.py:203, in BaseScope._ensure_kaleido(self)
#     201 if startup_response.get("code", 0) != 0:
#     202     self._proc.wait()
# --> 203     raise ValueError(startup_response.get("message", "Failed to start Kaleido subprocess"))
#
# ValueError: --plotlyjs argument is not a valid URL or file path:

# %% [markdown]
# Fit model on full dataset:

# %%
model.fit(
    X_train,
    y_train,
    verbose_eval=50,
    early_stopping_rounds=50,
    cat_features=categorical_indices,
    use_best_model=False,
    plot=True
)

model.save_model(outfolder / 'catboost_model_titanic_v2.cbm')
joblib.dump(params, outfolder / 'model_params_v2.pkl')
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	learn: 0.7321429	total: 21.6ms	remaining: 3.5s
# 50:	learn: 0.8535826	total: 959ms	remaining: 2.11s
# 100:	learn: 0.8813559	total: 1.94s	remaining: 1.19s
# 150:	learn: 0.9115854	total: 2.82s	remaining: 224ms
# 162:	learn: 0.9160305	total: 3.04s	remaining: 0us
# ['results\\model_params_v2.pkl']

# %% [markdown]
# And now to copy paste the train preprocessing code to preprocess the test set, and run a prediction:

# %%
df_test = pd.read_csv(download_folder / "test.csv")
df_test = df_test.drop(columns=["Ticket"])
df_test_id = df_test.pop("PassengerId")
df_test = df_test.fillna({"Embarked": "N", "Age": X_train["Age"].mean()})

pattern = r'([A-Za-z]+)(\d+)'
matches = df_test['Cabin'].str.extractall(pattern)
matches.reset_index(inplace=True)
result = matches.pivot(index='level_0', columns='match', values=[0, 1])
result.columns = [f"{col[0]}_{col[1]}" for col in result.columns]
df_test = df_test.join(result[["0_0", "1_0"]])
df_test["1_0"] = df_test["1_0"].astype(float)
df_test = df_test.fillna({"0_0": "N", "1_0": X_train["CabinNumber"].mean()})
df_test["1_0"] = df_test["1_0"].astype(int)
df_test = df_test.rename(columns={"0_0": "Deck", "1_0": "CabinNumber"})

df_test["Title"] = df_test["Name"].apply(extract_title)

df_test.drop(columns=["Cabin", "Name"], axis=1, inplace=True)
df_test["Title"].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Ms', 'Col', 'Rev', 'Dr', 'Dona'],
#       dtype=object)

# %%
preds = model.predict(df_test[X_train.columns])

# %% [markdown]
# Get the shapley overview plot showing the importance of the new features as well:

# %%
import shap
import matplotlib.pyplot as plt
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(df_test[X_train.columns])

shap.summary_plot(shap_values, df_test, show=False)
plt.savefig(outfolder / "test_shap_overall_v2.png")

# %% [markdown]
# And finally let's get the score on the test set:

# %%
df_test["PassengerId"] = df_test_id
df_test["Survived"] = preds

df_test[["PassengerId", "Survived"]].to_csv(outfolder / "predictions_v2.csv", index=False)

# %% [markdown]
# And submitting again to kaggle we get a slight improvement but with the client happier that we used all the data at least:
#
# ![screenshot of kaggle submission page v2 with prediction performance of 0.76555](results/kaggle_result_v2.png "Kaggle Result")
